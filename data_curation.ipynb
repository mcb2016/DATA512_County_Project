# %% [markdown]
# # DATA CURATION
#
# This script will serve to curate our two dataset: one which deals with the politicians by country provided by the Wikimedia API, another is a world population dataset provided by the Population Reference Bureau.

# %%
# First, let's import the modules that we'll be using to curate the data

import pandas as pd
import numpy as np
import string
import os

# %%
# Now we'll read in our data

demographics_by_case = pd.read_csv("raw_data/covid19_case_demographics.csv")

economic_data = pd.read_excel("raw_data/MOSLURN.xls", skiprows = 10)
stlouis_cases_over_time = pd.read_csv("raw_data/City-of-St-Louis-COVID-19-Case-Data.csv")
metrics_by_county = pd.read_csv("raw_data/MetricsbyCounty.csv")
demographics = pd.read_csv("raw_data/demographics.csv")

# %% [markdown]
# We'll need a dataframe that contains the population/cases for the 10 most populous counties in Missouri. Let's first modify our metrics by county dataset to only reflect the following counties: St. Louis, Jackson, St. Charles, St. Louis City, Greene, Jefferson, Boone, Jasper, Cass

# %%
counties = ['ST LOUIS', 'JACKSON', 'ST CHARLES', 'ST LOUIS CITY', 'GREENE', 'CLAY', 'JEFFERSON', 'BOONE', 'JASPER', 'CASS']

st_louis_metrics = metrics_by_county[metrics_by_county['County'].isin(counties) ]

st_louis_metrics.head(20)
# Out:
#     County                                    Measure Names  \
# 135  BOONE                                       Population
# 136  BOONE                             * Positive PCR Cases
# 137  BOONE                         * Positive Antigen Cases
# 138  BOONE                                 Confirmed Deaths
# 139  BOONE                                        PCR Tests
# 140  BOONE                                    Antigen Tests
# 141  BOONE               * 7 Day Range (Recent) - PCR Cases
# 142  BOONE          * 7 Day Range (Recent) - Antigen Cases
# 143  BOONE                           7-Day Confirmed Deaths
# 144  BOONE                                  7-Day PCR Tests
# 145  BOONE           * 7 Day Range (Recent) - Antigen Tests
# 146  BOONE           7-Day PCR Positivity Rate (CDC Method)
# 147  BOONE    * 7-Day Test Antigen Positivity Rate (Recent)
# 148  BOONE             7-Day Confirmed (PCR) Cases per 100k
# 149  BOONE  * 7 Day Range (Recent) - Antigen Cases per 100k
# 270   CASS                                       Population
# 271   CASS                             * Positive PCR Cases
# 272   CASS                         * Positive Antigen Cases
# 273   CASS                                 Confirmed Deaths
# 274   CASS                                        PCR Tests
#
#     7-Day Range End Date 7-Day Range Start Date Dashboard Update Date  \
# 135            11/6/2021             10/31/2021             11/9/2021
# 136            11/6/2021             10/31/2021             11/9/2021
# 137            11/6/2021             10/31/2021             11/9/2021
# 138            11/6/2021             10/31/2021             11/9/2021
# 139            11/6/2021             10/31/2021             11/9/2021
# 140            11/6/2021             10/31/2021             11/9/2021
# 141            11/6/2021             10/31/2021             11/9/2021
# 142            11/6/2021             10/31/2021             11/9/2021
# 143            11/6/2021             10/31/2021             11/9/2021
# 144            11/6/2021             10/31/2021             11/9/2021
# 145            11/6/2021             10/31/2021             11/9/2021
# 146            11/6/2021             10/31/2021             11/9/2021
# 147            11/6/2021             10/31/2021             11/9/2021
# 148            11/6/2021             10/31/2021             11/9/2021
# 149            11/6/2021             10/31/2021             11/9/2021
# 270            11/6/2021             10/31/2021             11/9/2021
# 271            11/6/2021             10/31/2021             11/9/2021
# 272            11/6/2021             10/31/2021             11/9/2021
# 273            11/6/2021             10/31/2021             11/9/2021
# 274            11/6/2021             10/31/2021             11/9/2021
#
#     Most Recent Test Date Measure Values
# 135             11/8/2021        180,463
# 136             11/8/2021         22,496
# 137             11/8/2021          2,702
# 138             11/8/2021            144
# 139             11/8/2021        284,956
# 140             11/8/2021         55,991
# 141             11/8/2021            136
# 142             11/8/2021             25
# 143             11/8/2021              0
# 144             11/8/2021          2,671
# 145             11/8/2021            785
# 146             11/8/2021    5.466117559
# 147             11/8/2021    3.949044586
# 148             11/8/2021   75.361708494
# 149             11/8/2021   13.853255238
# 270             11/8/2021        105,780
# 271             11/8/2021         11,925
# 272             11/8/2021          2,658
# 273             11/8/2021            170
# 274             11/8/2021        136,265

# %% [markdown]
# We'll save a subset of this dataframe that reflects the total number of cases in these counties over the course of the pandemic

# %%
columns = ['Population', '* Positive PCR Cases']

cases = st_louis_metrics[st_louis_metrics['Measure Names'].isin(columns)]

cases.to_csv('final_data/Missouri_cases_10_county.csv')

# %% [markdown]
# We'll save another subset of this dataframe that reflects the total number of deaths in the counties over the course of the pandemic

# %%
columns = ['Population', 'Deaths']

deaths = st_louis_metrics[st_louis_metrics['Measure Names'].isin(columns)]

deaths.to_csv('final_data/Missouri_deaths_10_county.csv')

# %% [markdown]
# Next We'll subset our economic dataframe to reflect the time period of unemployment during the course of the COVID-19 pandemic
#
# NOTE: The MOSLURN attribute measures the unemployment rate in the county for a given month

# %%
covid_econ_data = economic_data[economic_data['observation_date'] >= '2020-03-01' ]

covid_econ_data.head()
# Out:
#     observation_date  MOSLURN
# 362       2020-03-01      4.0
# 363       2020-04-01     11.5
# 364       2020-05-01     10.3
# 365       2020-06-01      9.0
# 366       2020-07-01      7.9

# %%
# Let's save this daframe to a csv file that we'll use later
covid_econ_data.to_csv('final_data/stlouis_covid_econ_data.csv')

# %% [markdown]
# Now we'll create a dataframe that has the hospitalizations by demographic in St. Louis County. To do this, we'll merge our hospitalizations_by_county and demographics dataframe using a location key, then subsetting the resulting dataframe for St. Louis County only
#
# NOTE: 29189 is the FIPS code for St. Louis County, MO

# %%
data = pd.read_csv("https://storage.googleapis.com/covid19-open-data/v3/epidemiology.csv")

# %%
data = data[data['location_key'] == 'US_MO']

data.head(20)
# Out:
#                date location_key  new_confirmed  new_deceased  new_recovered  \
# 8241435  2020-01-22        US_MO            0.0           0.0            NaN
# 8241436  2020-01-23        US_MO            0.0           0.0            NaN
# 8241437  2020-01-24        US_MO            0.0           0.0            NaN
# 8241438  2020-01-25        US_MO            0.0           0.0            NaN
# 8241439  2020-01-26        US_MO            0.0           0.0            NaN
# 8241440  2020-01-27        US_MO            0.0           0.0            NaN
# 8241441  2020-01-28        US_MO            0.0           0.0            NaN
# 8241442  2020-01-29        US_MO            0.0           0.0            NaN
# 8241443  2020-01-30        US_MO            0.0           0.0            NaN
# 8241444  2020-01-31        US_MO            0.0           0.0            NaN
# 8241445  2020-02-01        US_MO            0.0           0.0            NaN
# 8241446  2020-02-02        US_MO            0.0           0.0            NaN
# 8241447  2020-02-03        US_MO            0.0           0.0            NaN
# 8241448  2020-02-04        US_MO            0.0           0.0            NaN
# 8241449  2020-02-05        US_MO            0.0           0.0            NaN
# 8241450  2020-02-06        US_MO            0.0           0.0            NaN
# 8241451  2020-02-07        US_MO            0.0           0.0            NaN
# 8241452  2020-02-08        US_MO            0.0           0.0            NaN
# 8241453  2020-02-09        US_MO            0.0           0.0            NaN
# 8241454  2020-02-10        US_MO            0.0           0.0            NaN
#
#          new_tested  cumulative_confirmed  cumulative_deceased  \
# 8241435         NaN                   0.0                  0.0
# 8241436         NaN                   0.0                  0.0
# 8241437         NaN                   0.0                  0.0
# 8241438         NaN                   0.0                  0.0
# 8241439         NaN                   0.0                  0.0
# 8241440         NaN                   0.0                  0.0
# 8241441         NaN                   0.0                  0.0
# 8241442         NaN                   0.0                  0.0
# 8241443         NaN                   0.0                  0.0
# 8241444         NaN                   0.0                  0.0
# 8241445         NaN                   0.0                  0.0
# 8241446         NaN                   0.0                  0.0
# 8241447         NaN                   0.0                  0.0
# 8241448         NaN                   0.0                  0.0
# 8241449         NaN                   0.0                  0.0
# 8241450         NaN                   0.0                  0.0
# 8241451         NaN                   0.0                  0.0
# 8241452         NaN                   0.0                  0.0
# 8241453         NaN                   0.0                  0.0
# 8241454         NaN                   0.0                  0.0
#
#          cumulative_recovered  cumulative_tested
# 8241435                   NaN                NaN
# 8241436                   NaN                NaN
# 8241437                   NaN                NaN
# 8241438                   NaN                NaN
# 8241439                   NaN                NaN
# 8241440                   NaN                NaN
# 8241441                   NaN                NaN
# 8241442                   NaN                NaN
# 8241443                   NaN                NaN
# 8241444                   NaN                NaN
# 8241445                   NaN                NaN
# 8241446                   NaN                NaN
# 8241447                   NaN                NaN
# 8241448                   NaN                NaN
# 8241449                   NaN                NaN
# 8241450                   NaN                NaN
# 8241451                   NaN                NaN
# 8241452                   NaN                NaN
# 8241453                   NaN                NaN
# 8241454                   NaN                NaN

# %%
# Now we'll write this dataframe to a csv file to use for our analysis

data.to_csv('final_data/Missouri_case_rate_aggregate.csv')

# %% [markdown]
# Now we'll look which demographics were impacted the most by covid

# %%
url = 'https://raw.githubusercontent.com/nytimes/covid-19-data/master/rolling-averages/us-counties-2021.csv'
df = pd.read_csv(url)

st_louis = df[(df['county'] == 'St. Louis') & (df['state'] == 'Missouri')]

st_louis.head(20)
# Out:
#              date      geoid     county     state  cases  cases_avg  \
# 1651   2021-01-01  USA-29189  St. Louis  Missouri      0     456.57
# 4910   2021-01-02  USA-29189  St. Louis  Missouri    922     508.43
# 8169   2021-01-03  USA-29189  St. Louis  Missouri    597     554.14
# 11428  2021-01-04  USA-29189  St. Louis  Missouri    448     569.71
# 14687  2021-01-05  USA-29189  St. Louis  Missouri    454     525.00
# 17946  2021-01-06  USA-29189  St. Louis  Missouri      0     525.00
# 21205  2021-01-07  USA-29189  St. Louis  Missouri   1392     544.71
# 24464  2021-01-08  USA-29189  St. Louis  Missouri    554     545.88
# 27723  2021-01-09  USA-29189  St. Louis  Missouri    898     620.43
# 30982  2021-01-10  USA-29189  St. Louis  Missouri    455     600.14
# 34241  2021-01-11  USA-29189  St. Louis  Missouri    423     596.57
# 37500  2021-01-12  USA-29189  St. Louis  Missouri    484     600.86
# 40759  2021-01-13  USA-29189  St. Louis  Missouri    494     587.50
# 44018  2021-01-14  USA-29189  St. Louis  Missouri    456     537.71
# 47277  2021-01-15  USA-29189  St. Louis  Missouri    430     520.00
# 50536  2021-01-16  USA-29189  St. Louis  Missouri    537     468.43
# 53795  2021-01-17  USA-29189  St. Louis  Missouri    414     462.57
# 57054  2021-01-18  USA-29189  St. Louis  Missouri    343     451.14
# 60313  2021-01-19  USA-29189  St. Louis  Missouri    249     417.57
# 63572  2021-01-20  USA-29189  St. Louis  Missouri    482     415.86
#
#        cases_avg_per_100k  deaths  deaths_avg  deaths_avg_per_100k
# 1651                45.92       0        8.14                 0.82
# 4910                51.14       1        7.14                 0.72
# 8169                55.74       0        7.14                 0.72
# 11428               57.30       0        7.14                 0.72
# 14687               52.81      14        7.14                 0.72
# 17946               52.81       2        3.43                 0.34
# 21205               54.79      48        9.29                 0.93
# 24464               54.91      10        9.38                 0.94
# 27723               62.40       9       11.86                 1.19
# 30982               60.36       0       11.86                 1.19
# 34241               60.00       1        9.33                 0.94
# 37500               60.44      38       15.43                 1.55
# 40759               59.09      16       17.43                 1.75
# 44018               54.08      17       13.00                 1.31
# 47277               52.30       7       12.57                 1.26
# 50536               47.12       9       12.57                 1.26
# 53795               46.53       0       12.57                 1.26
# 57054               45.38       0       12.57                 1.26
# 60313               42.00       1        7.14                 0.72
# 63572               41.83      40       10.57                 1.06

# %% [markdown]
# Similar to what we did previously, lets extend this dataframe to include a couple of rural counties to determine whether individuals living in more rural counties are more or less at risk than people living in urban counties such as St. Louis

# %%
counties = ['St. Louis', 'Boone', 'Jackson', 'St. Charles']

counties_df = df[df['state'] == 'Missouri']

urban_v_rural = counties_df[counties_df['county'].isin(counties)]

urban_v_rural.head(20)
# Out:
#              date      geoid       county     state  cases  cases_avg  \
# 1651   2021-01-01  USA-29189    St. Louis  Missouri      0     456.57
# 1654   2021-01-01  USA-29183  St. Charles  Missouri      0     204.13
# 1704   2021-01-01  USA-29095      Jackson  Missouri    254     162.43
# 1742   2021-01-01  USA-29019        Boone  Missouri      0      87.57
# 4910   2021-01-02  USA-29189    St. Louis  Missouri    922     508.43
# 4913   2021-01-02  USA-29183  St. Charles  Missouri    309     194.20
# 4963   2021-01-02  USA-29095      Jackson  Missouri    148     167.57
# 5001   2021-01-02  USA-29019        Boone  Missouri      0      87.57
# 8169   2021-01-03  USA-29189    St. Louis  Missouri    597     554.14
# 8172   2021-01-03  USA-29183  St. Charles  Missouri    143     187.14
# 8222   2021-01-03  USA-29095      Jackson  Missouri    242     190.57
# 8260   2021-01-03  USA-29019        Boone  Missouri      0      87.57
# 11428  2021-01-04  USA-29189    St. Louis  Missouri    448     569.71
# 11431  2021-01-04  USA-29183  St. Charles  Missouri    173     207.00
# 11481  2021-01-04  USA-29095      Jackson  Missouri      0     190.57
# 11519  2021-01-04  USA-29019        Boone  Missouri    351     102.29
# 14687  2021-01-05  USA-29189    St. Louis  Missouri    454     525.00
# 14690  2021-01-05  USA-29183  St. Charles  Missouri     59     198.86
# 14740  2021-01-05  USA-29095      Jackson  Missouri    183     176.57
# 14778  2021-01-05  USA-29019        Boone  Missouri    109     101.00
#
#        cases_avg_per_100k  deaths  deaths_avg  deaths_avg_per_100k
# 1651                45.92       0        8.14                 0.82
# 1654                50.77       0        2.88                 0.72
# 1704                42.38       2        2.14                 0.56
# 1742                48.53       0        0.75                 0.42
# 4910                51.14       1        7.14                 0.72
# 4913                48.31       0        2.88                 0.72
# 4963                43.72       0        2.14                 0.56
# 5001                48.53       0        0.75                 0.42
# 8169                55.74       0        7.14                 0.72
# 8172                46.55       0        2.88                 0.72
# 8222                49.73       0        2.14                 0.56
# 8260                48.53       0        0.75                 0.42
# 11428               57.30       0        7.14                 0.72
# 11431               51.49       1        1.43                 0.36
# 11481               49.73       0        2.14                 0.56
# 11519               56.68       0        0.75                 0.42
# 14687               52.81      14        7.14                 0.72
# 14690               49.46       3        1.63                 0.40
# 14740               46.07      13        3.29                 0.86
# 14778               55.97       1        0.43                 0.24

# %% [markdown]
# Before we save this dataframe for our analyses, let's convert the daily rates to weekly rates. This will make it easier for us to plot trendline graphs as well as do group comparisons with other counties

# %%
from datetime import datetime

urban_v_rural.date = pd.to_datetime(urban_v_rural.date)

weekly_data = urban_v_rural.groupby('county').resample('W-Wed', label = 'right', closed = 'right', on = 'date').sum().reset_index().sort_values(by='date')

weekly_data.head(20)
# Out:
#           county       date  cases  cases_avg  cases_avg_per_100k  deaths  \
# 0          Boone 2021-01-06    631     574.71              318.48       2
# 49       Jackson 2021-01-06   1016    1067.42              278.52      17
# 147    St. Louis 2021-01-06   2421    3138.85              315.72      17
# 98   St. Charles 2021-01-06   1130    1214.76              302.16       4
# 148    St. Louis 2021-01-13   4700    4096.09              411.99     122
# 1          Boone 2021-01-13    738     788.18              436.74       3
# 50       Jackson 2021-01-13   1529    1377.31              359.38      19
# 99   St. Charles 2021-01-13   6553    1522.35              378.69       2
# 51       Jackson 2021-01-20    964    1210.00              315.72      11
# 100  St. Charles 2021-01-20   1260    1667.29              414.73       8
# 2          Boone 2021-01-20    596     646.70              358.37       4
# 149    St. Louis 2021-01-20   2911    3273.28              329.24      74
# 52       Jackson 2021-01-27    952     904.72              236.07      17
# 101  St. Charles 2021-01-27   1295    1268.67              315.57      12
# 150    St. Louis 2021-01-27   2559    2693.85              270.95      60
# 3          Boone 2021-01-27    589     605.73              335.66       2
# 53       Jackson 2021-02-03    774     908.72              237.12      14
# 151    St. Louis 2021-02-03   2183    2498.59              251.31     100
# 4          Boone 2021-02-03    396     475.85              263.70       1
# 102  St. Charles 2021-02-03    961    1030.72              256.40      20
#
#      deaths_avg  deaths_avg_per_100k
# 0          3.86                 2.16
# 49        14.85                 3.88
# 147       40.13                 4.04
# 98        13.33                 3.32
# 148       84.58                 8.49
# 1          3.07                 1.71
# 50        18.42                 4.80
# 99         7.91                 1.94
# 51        15.65                 4.09
# 100        7.43                 1.84
# 2          3.92                 2.20
# 149       80.99                 8.13
# 52        14.35                 3.74
# 101        6.70                 1.67
# 150       69.16                 6.94
# 3          3.24                 1.82
# 53        15.13                 3.95
# 151       61.50                 6.18
# 4          1.69                 0.95
# 102       14.23                 3.55

# %%
# we'll write this dataframe to csv file that we'll use in our subsequent analyses

weekly_data.to_csv('final_data/MO_stlouis_v_rural.csv')

# %% [markdown]
# Now we'll adjust our demographic dataframes for practical use in our analyses

# %%
demographics_by_case = demographics_by_case.drop('OBJECTID', axis = 1)

demographics_by_case.head()
# Out:
#            group  cases  rate_per_100k
# 0           Male  58920        12440.6
# 1         Female  71441        13605.9
# 2  9 and younger   8207         6919.8
# 3       10 to 19  15910        12494.8
# 4       20 to 29  22149        17474.0

# %%
demographics_by_deaths = demographics_by_deaths.drop('OBJECTID', axis = 1)

demographics_by_deaths.head()
# Out:
#             group  deaths  deaths_per_100k
# 0            Male    1234            260.6
# 1          Female    1322            251.8
# 2  39 and younger      17              3.4
# 3        40 to 49      53             44.4
# 4        50 to 59     143            100.1

# %%
# Now we'll write both dataframes to csv files

demographics_by_deaths.to_csv('final_data/demographics_by_deaths.csv')
demographics_by_case.to_csv('final_data/demographics_by_case.csv')
